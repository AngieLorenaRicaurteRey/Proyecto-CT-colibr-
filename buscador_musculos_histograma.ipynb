# %%
import matplotlib.pyplot as plt
from skimage.io import imread

img = imread(r"c:\Users\a.ricaurte\Desktop\colibri_1505.tif")

# Recortar una región donde está la fibra muscular (ajusta estas coordenadas según tu imagen)
x1, x2 = 520, 760
y1, y2 = 1290, 1445
roi = img[y1:y2, x1:x2]

# Mostrar imagen y rectángulo
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(img, cmap='gray')
rect = patches.Rectangle((x1, y1), x2 - x1, y2 - y1, linewidth=2, edgecolor='red', facecolor='none', linestyle='--')
ax.add_patch(rect)
ax.set_title("Verificación de la región muscular (ROI)")
plt.axis('off')
plt.show()

# Mostrar histograma de intensidades en esa región
plt.figure(figsize=(8, 4))
plt.hist(roi.ravel(), bins=100, color='darkred')
plt.title("Histograma de intensidades en la región muscular")
plt.xlabel("Intensidad (uint16)")
plt.ylabel("Frecuencia")
plt.grid(True)
plt.show()
